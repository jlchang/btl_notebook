# %% [raw]
# create an experiment CSV file
# located at /broad/hptmp/jlchang/dogChIPQCtest1/ChIPQC_experiment
# contents:
# "SampleID","Tissue","Factor","Replicate","bamReads","bamControl","ControlID","Peaks"
# "D57_H3K27ac","placenta","H3K27ac","1","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57/D57_H3K27ac_merge.bam","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57/D57_H3_merge.bam","D57_H3","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57chip_out/Peaks/bed/D57_H3K27ac_merge.bed"
# "D57_H3K27me3","placenta","H3K27me3","1","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57/D57_H3K27me3_merge.bam","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57/D57_H3_merge.bam","D57_H3","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57chip_out/Peaks/bed/D57_H3K27me3_merge.bed"
# "D57_H3k36me3","placenta","H3k36me3","1","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57/D57_H3K36me3_merge.bam","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57/D57_H3_merge.bam","D57_H3","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57chip_out/Peaks/bed/D57_H3K36me3_merge.bed"
# "D57_H3K4me1","placenta","H3K4me1","1","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57/D57_H3K4me1_merge.bam","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57/D57_H3_merge.bam","D57_H3","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57chip_out/Peaks/bed/D57_H3K4me1_merge.bed"
# "D57_H3K4me3","placenta","H3K4me3","1","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57/D57_H3K4me3_merge.bam","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57/D57_H3_merge.bam","D57_H3","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D57chip_out/Peaks/bed/D57_H3K4me3_merge.bed"
# "D70_H3K27ac","placenta","H3K27ac","2","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70/D70_H3K27ac_merge.bam","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70/D70_H3_merge.bam","D70_H3","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70chip_out/Peaks/bed/D70_H3K27ac_merge.bed"
# "D70_H3K27me3","placenta","H3K27me3","2","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70/D70_H3K27me3_merge.bam","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70/D70_H3_merge.bam","D70_H3","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70chip_out/Peaks/bed/D70_H3K27me3_merge.bed"
# "D70_H3k36me3","placenta","H3k36me3","2","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70/D70_H3K36me3_merge.bam","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70/D70_H3_merge.bam","D70_H3","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70chip_out/Peaks/bed/D70_H3K36me3_merge.bed"
# "D70_H3K4me1","placenta","H3K4me1","2","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70/D70_H3K4me1_merge.bam","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70/D70_H3_merge.bam","D70_H3","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70chip_out/Peaks/bed/D70_H3K4me1_merge.bed"
# "D70_H3K4me3","placenta","H3K4me3","2","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70/D70_H3K4me3_merge.bam","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70/D70_H3_merge.bam","D70_H3","/btl/projects/advancedlibraryprep/chip_seq/dog/C1-83_2016-09-04_2017-02-15/D70chip_out/Peaks/bed/D70_H3K4me3_merge.bed"
#
# Ross' file did not use quotes and was fine
#
# use .r-3.3.2
# R
# library(ChIPQC)
# foo <- ChIPQC("/broad/hptmp/jlchang/dogChIPQCtest1/ChIPQC_experiment.csv",,"chr1")
# ChIPQCreport(experiment = "foo", facet=TRUE,reportName="dogChIPQC",reportFolder="ChIPQC",facetBy="Factor",colourBy=c("Replicate"))
#
#
#
# Had to delete empty bed files and bed files that only had headers
# humantestK27me3 <- ChIPQC("/broad/hptmp/jlchang/dogChIPQCtest1/humantestK27me3.csv",,"1")
# ChIPQCreport(humantestK27me3,reportFolder="/broad/hptmp/jlchang/dogChIPQCtest1/humantestK27me3", facet=FALSE)

# %% [raw]
# #failed when providing calls file instead of bed file
# R command line test
# use .r-3.3.2
# Rlibrary(ChIPQC)
# ChIPQC("/broad/hptmp/jlchang/dogChIPQCtest1/ChIPQC_experiment.csv",,"chr1")
# #no genome annotation specified (not available for dog)
# #should ask Ross for repeatmasker blacklist
# > ChIPQC("/broad/hptmp/jlchang/dogChIPQCtest1/ChIPQC_experiment.csv",,"chr1")
# D57_H3K27ac placenta H3K27ac   1 fp4
# D57_H3K27me3 placenta H3K27me3   1 fp4
# D57_H3k36me3 placenta H3k36me3   1 fp4
# D57_H3K4me1 placenta H3K4me1   1 fp4
# D57_H3K4me3 placenta H3K4me3   1 fp4
# D70_H3K27ac placenta H3K27ac   1 fp4
# D70_H3K27me3 placenta H3K27me3   1 fp4
# D70_H3k36me3 placenta H3k36me3   1 fp4
# D70_H3K4me1 placenta H3K4me1   1 fp4
# D70_H3K4me3 placenta H3K4me3   1 fp4
# Computing metrics for 12 samples...
# list
# Bam file has 39 contigs
# Calculating coverage histogram for chr1
#
# Calculating SSD for chr1
#
# Calculating unique positions per strand for chr1
#
# Calculating shift for chr1
#
#  300 / 300
# Error in names(res) <- nms :
#   'names' attribute [12] must be the same length as the vector [4]
# In addition: Warning message:
# stop worker failed:
#   'clear_cluster' receive data failed:
#   reached elapsed time limit
# > Error in serialize(data, node$con, xdr = FALSE) : ignoring SIGPIPE signal
# Error in serialize(data, node$con, xdr = FALSE) : ignoring SIGPIPE signal
# In addition: Warning messages:
# 1: In if (is.na(peaks)) peaks = NULL :
#   the condition has length > 1 and only the first element will be used
# 2: In GetGRanges(bedFile, as.vector(names(ChrLengths)), names(ChrLengths)[k]) :
#   NAs introduced by coercion
# Error in serialize(data, node$con, xdr = FALSE) : ignoring SIGPIPE signal
# In addition: Warning messages:
# 1: In if (is.na(peaks)) peaks = NULL :
#   the condition has length > 1 and only the first element will be used
# 2: In GetGRanges(bedFile, as.vector(names(ChrLengths)), names(ChrLengths)[k]) :
#   NAs introduced by coercion
# Error in serialize(data, node$con, xdr = FALSE) : ignoring SIGPIPE signal
# In addition: Warning messages:
# 1: In if (is.na(peaks)) peaks = NULL :
#   the condition has length > 1 and only the first element will be used
# 2: In GetGRanges(bedFile, as.vector(names(ChrLengths)), names(ChrLengths)[k]) :
#   NAs introduced by coercion
# Error in serialize(data, node$con, xdr = FALSE) : ignoring SIGPIPE signal
# In addition: Warning messages:
# 1: In if (is.na(peaks)) peaks = NULL :
#   the condition has length > 1 and only the first element will be used
# 2: In GetGRanges(bedFile, as.vector(names(ChrLengths)), names(ChrLengths)[k]) :
#   NAs introduced by coercion

# %% [raw]
# signature(experiment = "ChIPQCexperiment", facet=TRUE, reportName="ChIPQC", reportFolder="ChIPQC",facetBy=c("Tissue","Factor","Condition","Treatment"),colourBy=c("Replicate"))}}
#
# experiment \tab \code{\link{ChIPQCexperiment}} object\cr
# facet \tab logical indicating whether or not to facet using experimental metadata.\cr
# reportName \tab filename of main report file (.html).\cr
# reportFolder \tab directory name where plot graphics will be saved\cr
# facetBy \tab metadata fields to use for faceting\cr
# colourBy \tab metadata field to color by\cr
